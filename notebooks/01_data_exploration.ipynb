# %% [markdown]
# # Smart Leaf AI - Data Exploration
#
# This notebook explores the leaf disease dataset and performs initial data analysis.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Configure visualization
# %matplotlib inline
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 2. Load Data
#
# Load your leaf disease dataset from the assets folder.

# %%
# Define data path
project_root = Path('..').resolve()
data_path = project_root / 'assets' / 'data'

print(f"Project Root: {project_root}")
print(f"Data Path: {data_path}")

# Load your data here
# df = pd.read_csv(data_path / 'your_dataset.csv')

# %% [markdown]
# ## 3. Data Overview

# %%
# Display basic dataset information
# print(f"Dataset shape: {df.shape}")
# print(f"\nFirst few rows:\n{df.head()}")
# print(f"\nData types:\n{df.dtypes}")
# print(f"\nMissing values:\n{df.isnull().sum()}")

# %% [markdown]
# ## 4. Exploratory Data Analysis

# %%
# Add your exploratory analysis here
# Visualize distributions, correlations, and class balance

# %% [markdown]
# ## 5. Image Analysis (if using images)
#
# Load and visualize sample images from the dataset.

# %%
# from PIL import Image
# import glob

# # Load and display sample images
# image_path = data_path / 'images'
# if image_path.exists():
#     images = glob.glob(str(image_path / '*.jpg'))
#     # Display sample images

# %% [markdown]
# ## Notes
#
# - Update the data loading section with your actual dataset path
# - Add any specific exploratory analysis relevant to your use case
# - Document findings and insights
